# %%
from twitterscraper import query_tweets

list_of_tweets = query_tweets("outage OR blackout", 10)

#print the retrieved tweets to the screen:
for tweet in query_tweets("outage OR blackout", 10):
    print(tweet)

#Or save the retrieved tweets to file:
file = open("scrape_test.txt","w", encoding='utf-8')
for tweet in query_tweets("outage OR blackout", 10):
    file.write(tweet.text+'\n')
file.close()
# Out:
# INFO: {'User-Agent': 'Opera/9.80 (X11; Linux i686; Ubuntu/14.10) Presto/2.12.388 Version/12.16'}
# INFO: queries: ['outage OR blackout since:2006-03-21 until:2006-11-29', 'outage OR blackout since:2006-11-29 until:2007-08-10', 'outage OR blackout since:2007-08-10 until:2008-04-20', 'outage OR blackout since:2008-04-20 until:2008-12-30', 'outage OR blackout since:2008-12-30 until:2009-09-09', 'outage OR blackout since:2009-09-09 until:2010-05-21', 'outage OR blackout since:2010-05-21 until:2011-01-30', 'outage OR blackout since:2011-01-30 until:2011-10-11', 'outage OR blackout since:2011-10-11 until:2012-06-20', 'outage OR blackout since:2012-06-20 until:2013-03-01', 'outage OR blackout since:2013-03-01 until:2013-11-10', 'outage OR blackout since:2013-11-10 until:2014-07-22', 'outage OR blackout since:2014-07-22 until:2015-04-01', 'outage OR blackout since:2015-04-01 until:2015-12-11', 'outage OR blackout since:2015-12-11 until:2016-08-21', 'outage OR blackout since:2016-08-21 until:2017-05-02', 'outage OR blackout since:2017-05-02 until:2018-01-10', 'outage OR blackout since:2018-01-10 until:2018-09-21', 'outage OR blackout since:2018-09-21 until:2019-06-02', 'outage OR blackout since:2019-06-02 until:2020-02-11']
# INFO: Got 12 tweets (12 new).
# INFO: Got 32 tweets (20 new).
# INFO: Got 51 tweets (19 new).
# INFO: Got 70 tweets (19 new).
# INFO: Got 88 tweets (18 new).
# INFO: Got 107 tweets (19 new).
# INFO: Got 126 tweets (19 new).
# INFO: Got 146 tweets (20 new).
# INFO: Got 166 tweets (20 new).
# INFO: Got 185 tweets (19 new).
# INFO: Got 204 tweets (19 new).
# INFO: Got 224 tweets (20 new).
# INFO: Got 244 tweets (20 new).
# INFO: Got 263 tweets (19 new).
# INFO: Got 283 tweets (20 new).
# INFO: Got 303 tweets (20 new).
# INFO: Got 323 tweets (20 new).
# INFO: Got 343 tweets (20 new).
# INFO: Got 358 tweets (15 new).
# INFO: Got 377 tweets (19 new).
# INFO: queries: ['outage OR blackout since:2006-03-21 until:2006-11-29', 'outage OR blackout since:2006-11-29 until:2007-08-10', 'outage OR blackout since:2007-08-10 until:2008-04-20', 'outage OR blackout since:2008-04-20 until:2008-12-30', 'outage OR blackout since:2008-12-30 until:2009-09-09', 'outage OR blackout since:2009-09-09 until:2010-05-21', 'outage OR blackout since:2010-05-21 until:2011-01-30', 'outage OR blackout since:2011-01-30 until:2011-10-11', 'outage OR blackout since:2011-10-11 until:2012-06-20', 'outage OR blackout since:2012-06-20 until:2013-03-01', 'outage OR blackout since:2013-03-01 until:2013-11-10', 'outage OR blackout since:2013-11-10 until:2014-07-22', 'outage OR blackout since:2014-07-22 until:2015-04-01', 'outage OR blackout since:2015-04-01 until:2015-12-11', 'outage OR blackout since:2015-12-11 until:2016-08-21', 'outage OR blackout since:2016-08-21 until:2017-05-02', 'outage OR blackout since:2017-05-02 until:2018-01-10', 'outage OR blackout since:2018-01-10 until:2018-09-21', 'outage OR blackout since:2018-09-21 until:2019-06-02', 'outage OR blackout since:2019-06-02 until:2020-02-11']
# INFO: Got 20 tweets (20 new).
# INFO: Got 32 tweets (12 new).
# INFO: Got 52 tweets (20 new).
# INFO: Got 72 tweets (20 new).
# INFO: Got 91 tweets (19 new).
# INFO: Got 110 tweets (19 new).
# INFO: Got 129 tweets (19 new).
# INFO: Got 149 tweets (20 new).
# INFO: Got 168 tweets (19 new).
# INFO: Got 188 tweets (20 new).
# INFO: Got 208 tweets (20 new).
# INFO: Got 227 tweets (19 new).
# INFO: Got 245 tweets (18 new).
# INFO: Got 265 tweets (20 new).
# INFO: Got 284 tweets (19 new).
# INFO: Got 299 tweets (15 new).
# INFO: Got 318 tweets (19 new).
# INFO: Got 338 tweets (20 new).
# INFO: Got 357 tweets (19 new).
# INFO: Got 377 tweets (20 new).
# INFO: queries: ['outage OR blackout since:2006-03-21 until:2006-11-29', 'outage OR blackout since:2006-11-29 until:2007-08-10', 'outage OR blackout since:2007-08-10 until:2008-04-20', 'outage OR blackout since:2008-04-20 until:2008-12-30', 'outage OR blackout since:2008-12-30 until:2009-09-09', 'outage OR blackout since:2009-09-09 until:2010-05-21', 'outage OR blackout since:2010-05-21 until:2011-01-30', 'outage OR blackout since:2011-01-30 until:2011-10-11', 'outage OR blackout since:2011-10-11 until:2012-06-20', 'outage OR blackout since:2012-06-20 until:2013-03-01', 'outage OR blackout since:2013-03-01 until:2013-11-10', 'outage OR blackout since:2013-11-10 until:2014-07-22', 'outage OR blackout since:2014-07-22 until:2015-04-01', 'outage OR blackout since:2015-04-01 until:2015-12-11', 'outage OR blackout since:2015-12-11 until:2016-08-21', 'outage OR blackout since:2016-08-21 until:2017-05-02', 'outage OR blackout since:2017-05-02 until:2018-01-10', 'outage OR blackout since:2018-01-10 until:2018-09-21', 'outage OR blackout since:2018-09-21 until:2019-06-02', 'outage OR blackout since:2019-06-02 until:2020-02-11']
# <twitterscraper.tweet.Tweet object at 0x000001543D475988>
# <twitterscraper.tweet.Tweet object at 0x000001543D49A848>
# <twitterscraper.tweet.Tweet object at 0x000001543D49A948>
# <twitterscraper.tweet.Tweet object at 0x000001543D49AA88>
# <twitterscraper.tweet.Tweet object at 0x000001543D49ABC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D49ACC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D49AE08>
# <twitterscraper.tweet.Tweet object at 0x000001543D49AF08>
# <twitterscraper.tweet.Tweet object at 0x000001543D49D048>
# <twitterscraper.tweet.Tweet object at 0x000001543D49D1C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D49D408>
# <twitterscraper.tweet.Tweet object at 0x000001543D49D548>
# <twitterscraper.tweet.Tweet object at 0x000001543D49D748>
# <twitterscraper.tweet.Tweet object at 0x000001543D49D8C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D49DA08>
# <twitterscraper.tweet.Tweet object at 0x000001543D49DB48>
# <twitterscraper.tweet.Tweet object at 0x000001543D49DC88>
# <twitterscraper.tweet.Tweet object at 0x000001543D49DE08>
# <twitterscraper.tweet.Tweet object at 0x000001543D49DF48>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A0248>
# <twitterscraper.tweet.Tweet object at 0x000001543D49A288>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A0A08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A0B48>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A0C88>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A0E48>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A4088>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A42C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A4508>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A4748>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A4988>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A4BC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A4E08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A0948>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A64C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A65C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A6748>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A6948>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A6B88>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A6DC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A7048>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A7288>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A74C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A7708>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A7A48>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A7C48>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A7F88>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A9188>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A93C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A9608>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A9848>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A9A88>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A9D08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4A09C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4AD4C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4AD608>
# <twitterscraper.tweet.Tweet object at 0x000001543D4AD748>
# <twitterscraper.tweet.Tweet object at 0x000001543D4AD988>
# <twitterscraper.tweet.Tweet object at 0x000001543D4ADB88>
# <twitterscraper.tweet.Tweet object at 0x000001543D4ADDC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4AE048>
# <twitterscraper.tweet.Tweet object at 0x000001543D4AE248>
# <twitterscraper.tweet.Tweet object at 0x000001543D4AE488>
# <twitterscraper.tweet.Tweet object at 0x000001543D4AE6C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4AE8C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4AEB08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4AED08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B1088>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B1248>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B1488>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B17C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B1988>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B1BC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4AD0C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4AB2C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4AB448>
# <twitterscraper.tweet.Tweet object at 0x000001543D4AB648>
# <twitterscraper.tweet.Tweet object at 0x000001543D4AB808>
# <twitterscraper.tweet.Tweet object at 0x000001543D4ABA48>
# <twitterscraper.tweet.Tweet object at 0x000001543D4ABC48>
# <twitterscraper.tweet.Tweet object at 0x000001543D4ABE08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4ABFC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B2208>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B2408>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B2608>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B2808>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B2A08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B2CC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B2E48>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B2FC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B4208>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B4408>
# <twitterscraper.tweet.Tweet object at 0x000001543D4AD408>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B4AC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B4C08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B4CC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B4EC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B7108>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B7348>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B7588>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B7808>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B7B08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B7DC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B7F48>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B9188>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B9448>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B9648>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B98C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B9B88>
# <twitterscraper.tweet.Tweet object at 0x000001543D4B9E08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4BD048>
# <twitterscraper.tweet.Tweet object at 0x000001543D4AD448>
# <twitterscraper.tweet.Tweet object at 0x000001543D4BD8C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4BDA08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4BDB48>
# <twitterscraper.tweet.Tweet object at 0x000001543D4BDC48>
# <twitterscraper.tweet.Tweet object at 0x000001543D4BDE08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4BE0C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4BE308>
# <twitterscraper.tweet.Tweet object at 0x000001543D4BE548>
# <twitterscraper.tweet.Tweet object at 0x000001543D4BE788>
# <twitterscraper.tweet.Tweet object at 0x000001543D4BEA48>
# <twitterscraper.tweet.Tweet object at 0x000001543D4BED08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4BEF48>
# <twitterscraper.tweet.Tweet object at 0x000001543D4BF1C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4BF408>
# <twitterscraper.tweet.Tweet object at 0x000001543D4BF6C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4BF908>
# <twitterscraper.tweet.Tweet object at 0x000001543D4BFC48>
# <twitterscraper.tweet.Tweet object at 0x000001543D4BFE48>
# <twitterscraper.tweet.Tweet object at 0x000001543D4BD2C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4C6548>
# <twitterscraper.tweet.Tweet object at 0x000001543D4C66C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4C6808>
# <twitterscraper.tweet.Tweet object at 0x000001543D4C69C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4C6C88>
# <twitterscraper.tweet.Tweet object at 0x000001543D4C6EC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4C8088>
# <twitterscraper.tweet.Tweet object at 0x000001543D4C8288>
# <twitterscraper.tweet.Tweet object at 0x000001543D4C8488>
# <twitterscraper.tweet.Tweet object at 0x000001543D4C8688>
# <twitterscraper.tweet.Tweet object at 0x000001543D4C8888>
# <twitterscraper.tweet.Tweet object at 0x000001543D4C8A88>
# <twitterscraper.tweet.Tweet object at 0x000001543D4C8C88>
# <twitterscraper.tweet.Tweet object at 0x000001543D4C8F08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4CC108>
# <twitterscraper.tweet.Tweet object at 0x000001543D4CC308>
# <twitterscraper.tweet.Tweet object at 0x000001543D4CC4C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4CC6C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4CC908>
# <twitterscraper.tweet.Tweet object at 0x000001543D4BD3C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D1148>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D1308>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D14C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D1688>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D1888>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D1A88>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D1D48>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D1EC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D0108>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D0348>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D0548>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D0808>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D0AC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D0D88>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D5088>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D5288>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D5588>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D5788>
# <twitterscraper.tweet.Tweet object at 0x000001543D4BD508>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D5C88>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D5DC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D5F08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D7108>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D72C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D7548>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D7788>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D79C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D7B48>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D7D48>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D7F08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D91C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D9388>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D9608>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D97C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D9988>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D9B48>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D9D08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D9EC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4C61C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4DA608>
# <twitterscraper.tweet.Tweet object at 0x000001543D4DA788>
# <twitterscraper.tweet.Tweet object at 0x000001543D4DA948>
# <twitterscraper.tweet.Tweet object at 0x000001543D4DABC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4DAD88>
# <twitterscraper.tweet.Tweet object at 0x000001543D4DAF88>
# <twitterscraper.tweet.Tweet object at 0x000001543D4DC1C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4DC3C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4DC588>
# <twitterscraper.tweet.Tweet object at 0x000001543D4DC788>
# <twitterscraper.tweet.Tweet object at 0x000001543D4DC988>
# <twitterscraper.tweet.Tweet object at 0x000001543D4DCBC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4DCD88>
# <twitterscraper.tweet.Tweet object at 0x000001543D4DCF48>
# <twitterscraper.tweet.Tweet object at 0x000001543D4DF188>
# <twitterscraper.tweet.Tweet object at 0x000001543D4DF448>
# <twitterscraper.tweet.Tweet object at 0x000001543D4DF608>
# <twitterscraper.tweet.Tweet object at 0x000001543D4DF7C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4DF9C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4CCC48>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E30C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E3248>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E33C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E35C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E38C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E3B08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E3CC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E3E88>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E21C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E2348>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E2548>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E2708>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E2948>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E2B48>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E2D48>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E2F88>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E5208>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E5408>
# <twitterscraper.tweet.Tweet object at 0x000001543D4DA588>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E5A88>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E5BC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E5D08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E5F08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E6288>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E6448>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E6688>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E68C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E6C08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E6F48>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E9148>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E9348>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E9648>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E9848>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E9A88>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E9CC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4EA048>
# <twitterscraper.tweet.Tweet object at 0x000001543D4E5688>
# <twitterscraper.tweet.Tweet object at 0x000001543D4EA708>
# <twitterscraper.tweet.Tweet object at 0x000001543D4EA808>
# <twitterscraper.tweet.Tweet object at 0x000001543D4EA908>
# <twitterscraper.tweet.Tweet object at 0x000001543D4EAB08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4EAD08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4EAEC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4EC108>
# <twitterscraper.tweet.Tweet object at 0x000001543D4EC308>
# <twitterscraper.tweet.Tweet object at 0x000001543D4EC548>
# <twitterscraper.tweet.Tweet object at 0x000001543D4EC708>
# <twitterscraper.tweet.Tweet object at 0x000001543D4EC948>
# <twitterscraper.tweet.Tweet object at 0x000001543D4ECB08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4ECD08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4ECF48>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F0188>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F0388>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F0608>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F0808>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F0A08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4DA1C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F0F48>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F3088>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F31C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F3488>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F3648>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F3908>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F3AC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F3C88>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F3E88>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F40C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F42C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F44C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F46C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F48C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F4A88>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F4D08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F4F88>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F5148>
# <twitterscraper.tweet.Tweet object at 0x000001543D4EA488>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F5808>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F5948>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F5A08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F5BC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F5D88>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F93C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F9608>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F97C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F99C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F9B48>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F9D48>
# <twitterscraper.tweet.Tweet object at 0x000001543D4FC088>
# <twitterscraper.tweet.Tweet object at 0x000001543D4FC248>
# <twitterscraper.tweet.Tweet object at 0x000001543D4FC508>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F53C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4FCB08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4FCCC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4FCE08>
# <twitterscraper.tweet.Tweet object at 0x000001543D4FD088>
# <twitterscraper.tweet.Tweet object at 0x000001543D4FD2C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4FD488>
# <twitterscraper.tweet.Tweet object at 0x000001543D4FD748>
# <twitterscraper.tweet.Tweet object at 0x000001543D4FD908>
# <twitterscraper.tweet.Tweet object at 0x000001543D4FDAC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4FDD48>
# <twitterscraper.tweet.Tweet object at 0x000001543D4FE148>
# <twitterscraper.tweet.Tweet object at 0x000001543D4FE508>
# <twitterscraper.tweet.Tweet object at 0x000001543D4FE8C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4FEAC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4FEC88>
# <twitterscraper.tweet.Tweet object at 0x000001543D4FEE48>
# <twitterscraper.tweet.Tweet object at 0x000001543D503148>
# <twitterscraper.tweet.Tweet object at 0x000001543D503488>
# <twitterscraper.tweet.Tweet object at 0x000001543D4FC648>
# <twitterscraper.tweet.Tweet object at 0x000001543D503AC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D503C48>
# <twitterscraper.tweet.Tweet object at 0x000001543D503E48>
# <twitterscraper.tweet.Tweet object at 0x000001543D503FC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D505208>
# <twitterscraper.tweet.Tweet object at 0x000001543D505508>
# <twitterscraper.tweet.Tweet object at 0x000001543D5056C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D5059C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D505B48>
# <twitterscraper.tweet.Tweet object at 0x000001543D505E08>
# <twitterscraper.tweet.Tweet object at 0x000001543D508088>
# <twitterscraper.tweet.Tweet object at 0x000001543D508248>
# <twitterscraper.tweet.Tweet object at 0x000001543D508448>
# <twitterscraper.tweet.Tweet object at 0x000001543D508648>
# <twitterscraper.tweet.Tweet object at 0x000001543D508808>
# <twitterscraper.tweet.Tweet object at 0x000001543D508A08>
# <twitterscraper.tweet.Tweet object at 0x000001543D508C08>
# <twitterscraper.tweet.Tweet object at 0x000001543D508EC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D50C0C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D4FC9C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D50C908>
# <twitterscraper.tweet.Tweet object at 0x000001543D50C9C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D50CBC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D50CD88>
# <twitterscraper.tweet.Tweet object at 0x000001543D50CF88>
# <twitterscraper.tweet.Tweet object at 0x000001543D511188>
# <twitterscraper.tweet.Tweet object at 0x000001543D511448>
# <twitterscraper.tweet.Tweet object at 0x000001543D511688>
# <twitterscraper.tweet.Tweet object at 0x000001543D511988>
# <twitterscraper.tweet.Tweet object at 0x000001543D511B08>
# <twitterscraper.tweet.Tweet object at 0x000001543969A448>
# <twitterscraper.tweet.Tweet object at 0x000001543CEA5208>
# <twitterscraper.tweet.Tweet object at 0x000001543CE8FF08>
# <twitterscraper.tweet.Tweet object at 0x000001543CE8FC48>
# <twitterscraper.tweet.Tweet object at 0x000001543CE8F9C8>
# <twitterscraper.tweet.Tweet object at 0x000001543CE8F7C8>
# <twitterscraper.tweet.Tweet object at 0x000001543CE8F448>
# <twitterscraper.tweet.Tweet object at 0x000001543CE8F108>
# <twitterscraper.tweet.Tweet object at 0x000001543D4F5488>
# <twitterscraper.tweet.Tweet object at 0x000001543CE8D648>
# <twitterscraper.tweet.Tweet object at 0x000001543D4D5848>
# <twitterscraper.tweet.Tweet object at 0x000001543D49DB08>
# <twitterscraper.tweet.Tweet object at 0x000001543D499188>
# <twitterscraper.tweet.Tweet object at 0x000001543BBF3048>
# <twitterscraper.tweet.Tweet object at 0x000001543D398388>
# <twitterscraper.tweet.Tweet object at 0x000001543D3980C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D394F88>
# <twitterscraper.tweet.Tweet object at 0x000001543D394CC8>
# <twitterscraper.tweet.Tweet object at 0x000001543D394B88>
# <twitterscraper.tweet.Tweet object at 0x000001543D3949C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D394688>
# <twitterscraper.tweet.Tweet object at 0x000001543D3945C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D394348>
# <twitterscraper.tweet.Tweet object at 0x000001543D394148>
# <twitterscraper.tweet.Tweet object at 0x000001543D32EE08>
# <twitterscraper.tweet.Tweet object at 0x000001543D32EC48>
# <twitterscraper.tweet.Tweet object at 0x000001543D32E9C8>
# <twitterscraper.tweet.Tweet object at 0x000001543D32E888>
# INFO: Got 20 tweets (20 new).
# INFO: Got 39 tweets (19 new).
# INFO: Got 59 tweets (20 new).
# INFO: Got 78 tweets (19 new).
# INFO: Got 97 tweets (19 new).
# INFO: Got 109 tweets (12 new).
# INFO: Got 129 tweets (20 new).
# INFO: Got 149 tweets (20 new).
# INFO: Got 168 tweets (19 new).
# INFO: Got 188 tweets (20 new).
# INFO: Got 208 tweets (20 new).
# INFO: Got 228 tweets (20 new).
# INFO: Got 247 tweets (19 new).
# INFO: Got 266 tweets (19 new).
# INFO: Got 284 tweets (18 new).
# INFO: Got 303 tweets (19 new).
# INFO: Got 323 tweets (20 new).
# INFO: Got 338 tweets (15 new).
# INFO: Got 358 tweets (20 new).
# INFO: Got 377 tweets (19 new).

# %%
tweet.
# Out:
# 'GatesGrim89'
