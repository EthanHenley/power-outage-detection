# %%
from twitterscraper import query_tweets

list_of_tweets = query_tweets("outage OR blackout", 10)

#print the retrieved tweets to the screen:
for tweet in query_tweets("outage OR blackout", 10):
    print(tweet)

#Or save the retrieved tweets to file:
file = open("scrape_test.txt","w", encoding='utf-8')
for tweet in query_tweets("outage OR blackout", 10):
    file.write(tweet.text+'\n')
file.close()
# Out:
# INFO: {'User-Agent': 'Mozilla/5.0 (compatible, MSIE 11, Windows NT 6.3; Trident/7.0; rv:11.0) like Gecko'}
# INFO: queries: ['outage OR blackout since:2006-03-21 until:2006-11-29', 'outage OR blackout since:2006-11-29 until:2007-08-10', 'outage OR blackout since:2007-08-10 until:2008-04-20', 'outage OR blackout since:2008-04-20 until:2008-12-30', 'outage OR blackout since:2008-12-30 until:2009-09-10', 'outage OR blackout since:2009-09-10 until:2010-05-21', 'outage OR blackout since:2010-05-21 until:2011-01-30', 'outage OR blackout since:2011-01-30 until:2011-10-11', 'outage OR blackout since:2011-10-11 until:2012-06-21', 'outage OR blackout since:2012-06-21 until:2013-03-02', 'outage OR blackout since:2013-03-02 until:2013-11-10', 'outage OR blackout since:2013-11-10 until:2014-07-22', 'outage OR blackout since:2014-07-22 until:2015-04-02', 'outage OR blackout since:2015-04-02 until:2015-12-12', 'outage OR blackout since:2015-12-12 until:2016-08-22', 'outage OR blackout since:2016-08-22 until:2017-05-02', 'outage OR blackout since:2017-05-02 until:2018-01-11', 'outage OR blackout since:2018-01-11 until:2018-09-22', 'outage OR blackout since:2018-09-22 until:2019-06-03', 'outage OR blackout since:2019-06-03 until:2020-02-12']
# INFO: Got 20 tweets (20 new).
# INFO: Got 39 tweets (19 new).
# INFO: Got 58 tweets (19 new).
# INFO: Got 77 tweets (19 new).
# INFO: Got 89 tweets (12 new).
# INFO: Got 109 tweets (20 new).
# INFO: Got 129 tweets (20 new).
# INFO: Got 149 tweets (20 new).
# INFO: Got 169 tweets (20 new).
# INFO: Got 189 tweets (20 new).
# INFO: Got 209 tweets (20 new).
# INFO: Got 228 tweets (19 new).
# INFO: Got 247 tweets (19 new).
# INFO: Got 266 tweets (19 new).
# INFO: Got 286 tweets (20 new).
# INFO: Got 304 tweets (18 new).
# INFO: Got 324 tweets (20 new).
# INFO: Got 343 tweets (19 new).
# INFO: Got 362 tweets (19 new).
# INFO: Got 381 tweets (19 new).
# INFO: queries: ['outage OR blackout since:2006-03-21 until:2006-11-29', 'outage OR blackout since:2006-11-29 until:2007-08-10', 'outage OR blackout since:2007-08-10 until:2008-04-20', 'outage OR blackout since:2008-04-20 until:2008-12-30', 'outage OR blackout since:2008-12-30 until:2009-09-10', 'outage OR blackout since:2009-09-10 until:2010-05-21', 'outage OR blackout since:2010-05-21 until:2011-01-30', 'outage OR blackout since:2011-01-30 until:2011-10-11', 'outage OR blackout since:2011-10-11 until:2012-06-21', 'outage OR blackout since:2012-06-21 until:2013-03-02', 'outage OR blackout since:2013-03-02 until:2013-11-10', 'outage OR blackout since:2013-11-10 until:2014-07-22', 'outage OR blackout since:2014-07-22 until:2015-04-02', 'outage OR blackout since:2015-04-02 until:2015-12-12', 'outage OR blackout since:2015-12-12 until:2016-08-22', 'outage OR blackout since:2016-08-22 until:2017-05-02', 'outage OR blackout since:2017-05-02 until:2018-01-11', 'outage OR blackout since:2018-01-11 until:2018-09-22', 'outage OR blackout since:2018-09-22 until:2019-06-03', 'outage OR blackout since:2019-06-03 until:2020-02-12']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 60 tweets (20 new).
# INFO: Got 79 tweets (19 new).
# INFO: Got 98 tweets (19 new).
# INFO: Got 118 tweets (20 new).
# INFO: Got 137 tweets (19 new).
# INFO: Got 157 tweets (20 new).
# INFO: Got 177 tweets (20 new).
# INFO: Got 196 tweets (19 new).
# INFO: Got 215 tweets (19 new).
# INFO: Got 227 tweets (12 new).
# INFO: Got 247 tweets (20 new).
# INFO: Got 266 tweets (19 new).
# INFO: Got 286 tweets (20 new).
# INFO: Got 306 tweets (20 new).
# INFO: Got 324 tweets (18 new).
# INFO: Got 343 tweets (19 new).
# INFO: Got 362 tweets (19 new).
# INFO: Got 381 tweets (19 new).
# INFO: queries: ['outage OR blackout since:2006-03-21 until:2006-11-29', 'outage OR blackout since:2006-11-29 until:2007-08-10', 'outage OR blackout since:2007-08-10 until:2008-04-20', 'outage OR blackout since:2008-04-20 until:2008-12-30', 'outage OR blackout since:2008-12-30 until:2009-09-10', 'outage OR blackout since:2009-09-10 until:2010-05-21', 'outage OR blackout since:2010-05-21 until:2011-01-30', 'outage OR blackout since:2011-01-30 until:2011-10-11', 'outage OR blackout since:2011-10-11 until:2012-06-21', 'outage OR blackout since:2012-06-21 until:2013-03-02', 'outage OR blackout since:2013-03-02 until:2013-11-10', 'outage OR blackout since:2013-11-10 until:2014-07-22', 'outage OR blackout since:2014-07-22 until:2015-04-02', 'outage OR blackout since:2015-04-02 until:2015-12-12', 'outage OR blackout since:2015-12-12 until:2016-08-22', 'outage OR blackout since:2016-08-22 until:2017-05-02', 'outage OR blackout since:2017-05-02 until:2018-01-11', 'outage OR blackout since:2018-01-11 until:2018-09-22', 'outage OR blackout since:2018-09-22 until:2019-06-03', 'outage OR blackout since:2019-06-03 until:2020-02-12']
# <twitterscraper.tweet.Tweet object at 0x0000021FEAC76A88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACA3548>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACA3648>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACA3788>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACA3888>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACA3988>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACA3A88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACA3B88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACA3D08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACA3E88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACA3F88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACA8108>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACA8248>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACA8388>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACA8508>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACA8688>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACA87C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACA8948>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACA8AC8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACA8C48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACA2F48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACAC288>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACAC388>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACAC508>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACAC708>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACAC948>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACACB88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACACDC8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACAD048>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACAD288>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACAD4C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACAD808>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACADA08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACADD48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACADF08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACAE188>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACAE3C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACAE608>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACAE848>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACAEA88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACA34C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB0308>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB0448>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB0608>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB0848>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB0A48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB0C88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB0EC8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB2108>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB2348>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB2588>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB2788>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB29C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB2BC8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB2F48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB5188>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB5408>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB5788>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB5988>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB5C08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACA3108>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB8248>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB8348>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB8488>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB8648>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB8848>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB8A08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB8C08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB8E48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB90C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB92C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB9588>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB9808>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB9A88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB9D48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB9F08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACBC208>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACBC3C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACBC5C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACA2348>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACBCC08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACBCD48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACBCEC8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACBF108>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACBF388>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACBF608>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACBF848>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACBFA88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACBFCC8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACBFF88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACC1288>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACC14C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACC1708>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACC1948>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACC1C08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACC1E48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACC21C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACC23C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACA8E08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACC2A88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACC2B88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACC2C88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACC2E88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACC50C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACC5288>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACC5488>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACC5688>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACC58C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACC5A88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACC5CC8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACC5E88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACC80C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACC8308>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACC8508>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACC8708>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACC8988>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACC8B88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACC8D88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACC26C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACCD448>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACCD5C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACCD708>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACCD8C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACCDAC8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACCDCC8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACCDF88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACCC148>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACCC348>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACCC588>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACCC788>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACCCA48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACCCD08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACCCFC8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACCF288>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACCF448>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACCF708>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACCF8C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACC29C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACD30C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACD3208>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACD33C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACD35C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACD3808>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACD3A08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACD3C48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACD3E88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACD4108>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACD4348>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACD4588>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACD47C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACD4A08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACD4C48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACD4E48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACD51C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACD53C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACD55C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACD5808>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACCD048>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACD5E48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACD5F48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACD7108>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACD7348>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACD7548>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACD7788>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACD7988>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACD7B88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACD7DC8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACDA148>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACDA308>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACDA608>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACDA808>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACDAA08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACDAC08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACDAE08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACDB088>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACDB288>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACDB508>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACCD3C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACDBB48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACDBC48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACDBD48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACDD048>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACDD208>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACDD4C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACDD688>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACDD848>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACDDA48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACDDC48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACDDE48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE1088>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE1288>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE1488>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE1648>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE18C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE1B48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE1CC8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACDB708>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE3448>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE35C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE3748>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE3948>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE3C48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE3E88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE5088>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE5248>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE5548>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE56C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE58C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE5A88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE5CC8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE5EC8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE6108>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE6348>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE6588>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE6788>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE3108>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE6E08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE6F48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE7108>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE7308>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE7508>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE7748>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE7988>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE7BC8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE7E08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACEC088>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACEC2C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE3308>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACEC8C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACECA48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACECC88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACECE08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACF3048>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACF3348>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACF3508>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACF3808>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACF3988>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACF3C48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACF3E88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACF5088>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACF5288>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACF5488>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACF5648>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACF5848>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACF5A48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACF5D08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACF5EC8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACE6D88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACF7548>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACF7708>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACF7888>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACF7A88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACF7D08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACF7F08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACF9148>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACF9348>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACF95C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACF97C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACF9A48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACF9C08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACF9E08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACFA088>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACFA288>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACFA448>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACFA688>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACFA848>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACEC808>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACFAE08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACFAEC8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACFAFC8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACFC208>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACFC408>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACFC608>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACFC7C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACFC9C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACFCB88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACFCD88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACFF108>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACFF288>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACFF488>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACFF6C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACFF8C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACFFAC8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACFFCC8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACFFF48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD00188>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACEC848>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD00848>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD009C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD00B08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD00D88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD00F48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD03248>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD03408>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD03608>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD03888>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD03A48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD03CC8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD03E88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD04188>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD04388>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD04648>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD04808>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD04A08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD04C48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD04E48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACFAB08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD094C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD09588>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD09708>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD09908>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD09B08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD09DC8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD09FC8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD0A208>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD0A3C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD0A5C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD0A788>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD0A988>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD0AD48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD0AF48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD0C188>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD0C348>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD0C608>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACFAA88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD0CC48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD0CD48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD0CE48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD0F088>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD0F3C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD0F708>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD0FA08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD0FD88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD0FF88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD11188>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD11388>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD11588>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD117C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD11988>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD11C08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD11E08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD11FC8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAD15208>
# <twitterscraper.tweet.Tweet object at 0x0000021FEA695F88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEA695988>
# <twitterscraper.tweet.Tweet object at 0x0000021FEA6955C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEA695348>
# <twitterscraper.tweet.Tweet object at 0x0000021FEA695088>
# <twitterscraper.tweet.Tweet object at 0x0000021FEA693E08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEA693C88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEA693A48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEA693848>
# <twitterscraper.tweet.Tweet object at 0x0000021FEA693608>
# <twitterscraper.tweet.Tweet object at 0x0000021FEA6933C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACB5888>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACA8788>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAC9CFC8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEACA23C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEABA00C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAB9CFC8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAB9CCC8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAB9CB88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEA695FC8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAB9C588>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAB9C448>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAB9C148>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAB36F08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAB36D08>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAB36A88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAB367C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAB36708>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAB36408>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAB361C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAB32F88>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAB32D48>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAB32948>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAB32848>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAB325C8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAB32248>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAB2FEC8>
# <twitterscraper.tweet.Tweet object at 0x0000021FEAB2FD08>
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 52 tweets (12 new).
# INFO: Got 71 tweets (19 new).
# INFO: Got 91 tweets (20 new).
# INFO: Got 111 tweets (20 new).
# INFO: Got 131 tweets (20 new).
# INFO: Got 150 tweets (19 new).
# INFO: Got 169 tweets (19 new).
# INFO: Got 189 tweets (20 new).
# INFO: Got 208 tweets (19 new).
# INFO: Got 227 tweets (19 new).
# INFO: Got 246 tweets (19 new).
# INFO: Got 266 tweets (20 new).
# INFO: Got 285 tweets (19 new).
# INFO: Got 303 tweets (18 new).
# INFO: Got 323 tweets (20 new).
# INFO: Got 343 tweets (20 new).
# INFO: Got 362 tweets (19 new).
# INFO: Got 381 tweets (19 new).

# %%
tweet.user_id
# Out:
# '230165613'
