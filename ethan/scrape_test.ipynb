# %%
from twitterscraper import query_tweets

list_of_tweets = query_tweets("outage OR blackout", 10)

#print the retrieved tweets to the screen:
for tweet in query_tweets("outage OR blackout", 10):
    print(tweet)

#Or save the retrieved tweets to file:
file = open("test_tweets.txt","w", encoding='utf-8')
for tweet in query_tweets("outage OR blackout", 10):
    file.write(tweet.text+'\n')
file.close()
# Out:
# INFO: queries: ['outage OR blackout since:2006-03-21 until:2006-11-29', 'outage OR blackout since:2006-11-29 until:2007-08-10', 'outage OR blackout since:2007-08-10 until:2008-04-20', 'outage OR blackout since:2008-04-20 until:2008-12-29', 'outage OR blackout since:2008-12-29 until:2009-09-09', 'outage OR blackout since:2009-09-09 until:2010-05-21', 'outage OR blackout since:2010-05-21 until:2011-01-29', 'outage OR blackout since:2011-01-29 until:2011-10-10', 'outage OR blackout since:2011-10-10 until:2012-06-20', 'outage OR blackout since:2012-06-20 until:2013-03-01', 'outage OR blackout since:2013-03-01 until:2013-11-09', 'outage OR blackout since:2013-11-09 until:2014-07-21', 'outage OR blackout since:2014-07-21 until:2015-04-01', 'outage OR blackout since:2015-04-01 until:2015-12-10', 'outage OR blackout since:2015-12-10 until:2016-08-20', 'outage OR blackout since:2016-08-20 until:2017-05-01', 'outage OR blackout since:2017-05-01 until:2018-01-09', 'outage OR blackout since:2018-01-09 until:2018-09-20', 'outage OR blackout since:2018-09-20 until:2019-06-01', 'outage OR blackout since:2019-06-01 until:2020-02-10']
# INFO: Got 20 tweets (20 new).
# INFO: Got 32 tweets (12 new).
# INFO: Got 52 tweets (20 new).
# INFO: Got 72 tweets (20 new).
# INFO: Got 92 tweets (20 new).
# INFO: Got 112 tweets (20 new).
# INFO: Got 132 tweets (20 new).
# INFO: Got 151 tweets (19 new).
# INFO: Got 171 tweets (20 new).
# INFO: Got 191 tweets (20 new).
# INFO: Got 211 tweets (20 new).
# INFO: Got 231 tweets (20 new).
# INFO: Got 249 tweets (18 new).
# INFO: Got 269 tweets (20 new).
# INFO: Got 286 tweets (17 new).
# INFO: Got 304 tweets (18 new).
# INFO: Got 323 tweets (19 new).
# INFO: Got 342 tweets (19 new).
# INFO: Got 362 tweets (20 new).
# INFO: Got 382 tweets (20 new).
# INFO: queries: ['outage OR blackout since:2006-03-21 until:2006-11-29', 'outage OR blackout since:2006-11-29 until:2007-08-10', 'outage OR blackout since:2007-08-10 until:2008-04-20', 'outage OR blackout since:2008-04-20 until:2008-12-29', 'outage OR blackout since:2008-12-29 until:2009-09-09', 'outage OR blackout since:2009-09-09 until:2010-05-21', 'outage OR blackout since:2010-05-21 until:2011-01-29', 'outage OR blackout since:2011-01-29 until:2011-10-10', 'outage OR blackout since:2011-10-10 until:2012-06-20', 'outage OR blackout since:2012-06-20 until:2013-03-01', 'outage OR blackout since:2013-03-01 until:2013-11-09', 'outage OR blackout since:2013-11-09 until:2014-07-21', 'outage OR blackout since:2014-07-21 until:2015-04-01', 'outage OR blackout since:2015-04-01 until:2015-12-10', 'outage OR blackout since:2015-12-10 until:2016-08-20', 'outage OR blackout since:2016-08-20 until:2017-05-01', 'outage OR blackout since:2017-05-01 until:2018-01-09', 'outage OR blackout since:2018-01-09 until:2018-09-20', 'outage OR blackout since:2018-09-20 until:2019-06-01', 'outage OR blackout since:2019-06-01 until:2020-02-10']
# INFO: Got 12 tweets (12 new).
# INFO: Got 32 tweets (20 new).
# INFO: Got 52 tweets (20 new).
# INFO: Got 72 tweets (20 new).
# INFO: Got 92 tweets (20 new).
# INFO: Got 112 tweets (20 new).
# INFO: Got 132 tweets (20 new).
# INFO: Got 152 tweets (20 new).
# INFO: Got 172 tweets (20 new).
# INFO: Got 190 tweets (18 new).
# INFO: Got 208 tweets (18 new).
# INFO: Got 228 tweets (20 new).
# INFO: Got 247 tweets (19 new).
# INFO: Got 267 tweets (20 new).
# INFO: Got 287 tweets (20 new).
# INFO: Got 306 tweets (19 new).
# INFO: Got 325 tweets (19 new).
# INFO: Got 345 tweets (20 new).
# INFO: Got 362 tweets (17 new).
# INFO: Got 382 tweets (20 new).
# INFO: queries: ['outage OR blackout since:2006-03-21 until:2006-11-29', 'outage OR blackout since:2006-11-29 until:2007-08-10', 'outage OR blackout since:2007-08-10 until:2008-04-20', 'outage OR blackout since:2008-04-20 until:2008-12-29', 'outage OR blackout since:2008-12-29 until:2009-09-09', 'outage OR blackout since:2009-09-09 until:2010-05-21', 'outage OR blackout since:2010-05-21 until:2011-01-29', 'outage OR blackout since:2011-01-29 until:2011-10-10', 'outage OR blackout since:2011-10-10 until:2012-06-20', 'outage OR blackout since:2012-06-20 until:2013-03-01', 'outage OR blackout since:2013-03-01 until:2013-11-09', 'outage OR blackout since:2013-11-09 until:2014-07-21', 'outage OR blackout since:2014-07-21 until:2015-04-01', 'outage OR blackout since:2015-04-01 until:2015-12-10', 'outage OR blackout since:2015-12-10 until:2016-08-20', 'outage OR blackout since:2016-08-20 until:2017-05-01', 'outage OR blackout since:2017-05-01 until:2018-01-09', 'outage OR blackout since:2018-01-09 until:2018-09-20', 'outage OR blackout since:2018-09-20 until:2019-06-01', 'outage OR blackout since:2019-06-01 until:2020-02-10']
# <twitterscraper.tweet.Tweet object at 0x0000028AF34AFF48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30F3088>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30F38C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30F3988>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30F3E88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30DF148>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30DF248>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30DF308>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30DF948>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30DFCC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30DFF08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30DF088>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30F3F48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30DF988>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30DFD48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30DF848>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3977948>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3977C48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3977288>
# <twitterscraper.tweet.Tweet object at 0x0000028AF39CD908>
# <twitterscraper.tweet.Tweet object at 0x0000028AF39CD5C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E7C7C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E7C448>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E7CA88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E7C8C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E7C0C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF34D43C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF34D4088>
# <twitterscraper.tweet.Tweet object at 0x0000028AF34D4E48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF34D4E88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF34D4408>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2DCF288>
# <twitterscraper.tweet.Tweet object at 0x0000028AF34AF748>
# <twitterscraper.tweet.Tweet object at 0x0000028AF4190448>
# <twitterscraper.tweet.Tweet object at 0x0000028AF4190888>
# <twitterscraper.tweet.Tweet object at 0x0000028AF4190B08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF4190B88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3AF9208>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30CE1C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30CEDC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30CEB08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30CEF08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30CE388>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30CE608>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30CED08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF40C4B48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF40C4BC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF40C4248>
# <twitterscraper.tweet.Tweet object at 0x0000028AF40C4208>
# <twitterscraper.tweet.Tweet object at 0x0000028AF40C4648>
# <twitterscraper.tweet.Tweet object at 0x0000028AF40C4A08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF38F93C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF34AFEC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3146D08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3146388>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3146788>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3146508>
# <twitterscraper.tweet.Tweet object at 0x0000028AF31464C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3146688>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3146CC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3146EC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3A3C9C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF31015C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3101348>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3101948>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3101A48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3101848>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3101C08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3472408>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3472B88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF34720C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3472788>
# <twitterscraper.tweet.Tweet object at 0x0000028AF41905C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3472F88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF34721C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3A4F308>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3A4FE08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3F70608>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3F70208>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3F70948>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3F70BC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3F70D48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3F70E48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E8A108>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E8A908>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E8A448>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E8A188>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E8A688>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E8AE08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3A24288>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3A24148>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30FBC08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3472A88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF40A8808>
# <twitterscraper.tweet.Tweet object at 0x0000028AF40A8D88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF40A88C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF40A8748>
# <twitterscraper.tweet.Tweet object at 0x0000028AF40A8208>
# <twitterscraper.tweet.Tweet object at 0x0000028AF39D9788>
# <twitterscraper.tweet.Tweet object at 0x0000028AF39D9A88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3109548>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3109988>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3109608>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3109648>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3109DC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3109D88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3109BC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30EB2C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30EB3C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30EB0C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30EB888>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30EB588>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3924188>
# <twitterscraper.tweet.Tweet object at 0x0000028AF41C8948>
# <twitterscraper.tweet.Tweet object at 0x0000028AF41C8988>
# <twitterscraper.tweet.Tweet object at 0x0000028AF41C8A88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF41C8488>
# <twitterscraper.tweet.Tweet object at 0x0000028AF41C8688>
# <twitterscraper.tweet.Tweet object at 0x0000028AF41C8108>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3121D48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF31219C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3121F08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3121088>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3121AC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3121588>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30D2C88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30D22C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30D2A48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30D2DC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30D2B48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30D2908>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2DB6708>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30FB908>
# <twitterscraper.tweet.Tweet object at 0x0000028AF40553C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF40550C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF4055808>
# <twitterscraper.tweet.Tweet object at 0x0000028AF4055AC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF40555C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF4055C48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30DC048>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30DC108>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30DC408>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30DCB88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30DCAC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30DC308>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30DCD88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF35860C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3586D08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF35861C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF35864C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3586EC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3586348>
# <twitterscraper.tweet.Tweet object at 0x0000028AF41C8348>
# <twitterscraper.tweet.Tweet object at 0x0000028AF311E548>
# <twitterscraper.tweet.Tweet object at 0x0000028AF311EE48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF311E388>
# <twitterscraper.tweet.Tweet object at 0x0000028AF311E948>
# <twitterscraper.tweet.Tweet object at 0x0000028AF311ED48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF311E2C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF41F97C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF41F9D48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF41F9AC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF41F9F88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF41F9888>
# <twitterscraper.tweet.Tweet object at 0x0000028AF41F9C08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF41F9288>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E86D08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E862C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E86B48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E86808>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E86188>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E86508>
# <twitterscraper.tweet.Tweet object at 0x0000028AF4055CC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E81F08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E81B48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E810C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E81D48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30F73C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30F7208>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30F7748>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30F7588>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30F7DC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30F74C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF39DD448>
# <twitterscraper.tweet.Tweet object at 0x0000028AF313B308>
# <twitterscraper.tweet.Tweet object at 0x0000028AF313B208>
# <twitterscraper.tweet.Tweet object at 0x0000028AF313B8C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF313B408>
# <twitterscraper.tweet.Tweet object at 0x0000028AF313BB08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF313BDC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E81688>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2EA9788>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2EA9FC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2EA98C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2EA9088>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2EA9548>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2EA9BC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3BCA7C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3104148>
# <twitterscraper.tweet.Tweet object at 0x0000028AF31047C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3104348>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3104608>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3104688>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3104888>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3174288>
# <twitterscraper.tweet.Tweet object at 0x0000028AF31747C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3174948>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3174E88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E81648>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3FA4948>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3FA4B48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3FA4B88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3FA4EC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3FA4588>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3FA4CC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3FA4DC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3144848>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3144CC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3144608>
# <twitterscraper.tweet.Tweet object at 0x0000028AF31445C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3144448>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3144388>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3144B08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3EDDF48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3EDD6C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3EDD708>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3EDD608>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3EDDAC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF311EAC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF407E748>
# <twitterscraper.tweet.Tweet object at 0x0000028AF407E788>
# <twitterscraper.tweet.Tweet object at 0x0000028AF407EC88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF407EFC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF407EE48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF407E648>
# <twitterscraper.tweet.Tweet object at 0x0000028AF310AC88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF310A108>
# <twitterscraper.tweet.Tweet object at 0x0000028AF310AB48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF310AC08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF310AE88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF310A948>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3573688>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3573888>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3573BC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF35737C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF35736C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3573548>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2EA90C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3140D88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3140508>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3140E08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3140788>
# <twitterscraper.tweet.Tweet object at 0x0000028AF31DC448>
# <twitterscraper.tweet.Tweet object at 0x0000028AF31DCD08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF31DCB48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF31DCB08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3129F48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF31293C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF31296C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3129A08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E67088>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E679C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E67C88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E67388>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3507908>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3507988>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3507048>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3140D48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3507EC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3507888>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3E43748>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3E43C48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3E431C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3E434C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3E43908>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3E439C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3E430C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30A2CC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30A2A88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30A2A48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30A2108>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30A2248>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30A2988>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30A2408>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3124048>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3124F08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3124788>
# <twitterscraper.tweet.Tweet object at 0x0000028AF35073C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3124608>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3124808>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E3B248>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E3B2C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E3B448>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E3B848>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E3BA88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E3BF48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E3B408>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E31F08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E313C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E31648>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E31E08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E319C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E31488>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30B0EC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30B05C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30B0608>
# <twitterscraper.tweet.Tweet object at 0x0000028AF407E2C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30D7308>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30D7388>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30D7688>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30D7448>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30D76C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30D7948>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30D7C48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30D7F08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3122EC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3122288>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3122848>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3122D88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E4F5C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E4F8C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E4F908>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E4F588>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E4FF08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E4FB08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3124408>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E77C88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E77F88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E77108>
# <twitterscraper.tweet.Tweet object at 0x0000028AF311A148>
# <twitterscraper.tweet.Tweet object at 0x0000028AF311A088>
# <twitterscraper.tweet.Tweet object at 0x0000028AF311AE48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF40FFE48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF40FFB08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF30AB108>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3169E48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E72308>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E72188>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E72388>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E72048>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E72708>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E72988>
# <twitterscraper.tweet.Tweet object at 0x0000028AF40E1088>
# <twitterscraper.tweet.Tweet object at 0x0000028AF40E1648>
# <twitterscraper.tweet.Tweet object at 0x0000028AF40E1FC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E77808>
# <twitterscraper.tweet.Tweet object at 0x0000028AF40E16C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF40E1988>
# <twitterscraper.tweet.Tweet object at 0x0000028AF40E1C48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF39E1A88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF39E1E48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3105148>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3105448>
# <twitterscraper.tweet.Tweet object at 0x0000028AF31052C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3105948>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3105E88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3105D48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3105648>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E03488>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E03288>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E03948>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E039C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E77BC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E034C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E03CC8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3FED288>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3FEDB48>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3FED648>
# <twitterscraper.tweet.Tweet object at 0x0000028AF40B2308>
# <twitterscraper.tweet.Tweet object at 0x0000028AF40B2C88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF40B2108>
# <twitterscraper.tweet.Tweet object at 0x0000028AF40B2448>
# <twitterscraper.tweet.Tweet object at 0x0000028AF40B2708>
# <twitterscraper.tweet.Tweet object at 0x0000028AF40B29C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF40B2E88>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3524488>
# <twitterscraper.tweet.Tweet object at 0x0000028AF35243C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF3524248>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E4AD08>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E4A1C8>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E4A608>
# <twitterscraper.tweet.Tweet object at 0x0000028AF2E4A888>
# INFO: Got 12 tweets (12 new).
# INFO: Got 32 tweets (20 new).
# INFO: Got 51 tweets (19 new).
# INFO: Got 69 tweets (18 new).
# INFO: Got 88 tweets (19 new).
# INFO: Got 108 tweets (20 new).
# INFO: Got 128 tweets (20 new).
# INFO: Got 148 tweets (20 new).
# INFO: Got 168 tweets (20 new).
# INFO: Got 188 tweets (20 new).
# INFO: Got 208 tweets (20 new).
# INFO: Got 228 tweets (20 new).
# INFO: Got 247 tweets (19 new).
# INFO: Got 267 tweets (20 new).
# INFO: Got 284 tweets (17 new).
# INFO: Got 304 tweets (20 new).
# INFO: Got 324 tweets (20 new).
# INFO: Got 342 tweets (18 new).
# INFO: Got 362 tweets (20 new).
# INFO: Got 382 tweets (20 new).
