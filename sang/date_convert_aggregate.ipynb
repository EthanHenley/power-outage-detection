# %%
import pandas as pd
import xlrd
import xlwt

# %%
# !pip install xlrd
# !pip install xlwt

# %%
test_data = xlrd.open_workbook('data/Table_B_1 - 2018.xlsx')

# %%
worksheet = test_data.sheet_by_index(0)

# %%
worksheet.cell(0,0).value
# Out:
# 'Table B.1 Major Disturbances and Unusual Occurrences, Year-to-Date 2018'

# %%
# convert to csv
read_file = pd.read_excel(r'data/Table_B_1 - 2018.xlsx', index_col=1, header = 1)

# %%
read_file.to_csv(r'data/2018.csv')

# %%
read_file.head(10)
# Out:
#        Year  Event Date and Time Restoration Date and Time  \
# Month
# 1.0    2018  01/01/2018  5:43 PM                .        .
# 1.0    2018  01/01/2018  6:21 PM       01/02/2018  6:11 PM
# 1.0    2018  01/01/2018  9:37 PM       01/02/2018 10:30 AM
# 1.0    2018  01/02/2018  6:45 AM       01/02/2018  9:00 AM
# 1.0    2018  01/02/2018  7:30 AM                .        .
# 1.0    2018  01/02/2018 10:00 AM       02/12/2018  8:00 AM
# 1.0    2018  01/15/2018  4:20 AM       01/18/2018  5:48 AM
# 1.0    2018  01/16/2018  1:57 PM       01/16/2018  2:32 PM
# 1.0    2018  01/16/2018  3:00 PM       01/18/2018  1:00 PM
# 1.0    2018  01/16/2018  3:00 PM       01/18/2018  1:00 PM
#
#                     Duration                    Utility/Power Pool  \
# Month
# 1.0      . Hours,  . Minutes       American Electric Power - Texas
# 1.0     23 Hours, 50 Minutes            Tennessee Valley Authority
# 1.0     12 Hours, 53 Minutes  Memphis Light Gas and Water Division
# ...

# %%
# convert to csv older data
read_file_2010 = pd.read_excel(r'data/epmxlfileb1 - 2010.xls', index_col=1, header = 1)

# %%
read_file_2010.head(10)
# Out:
#                                                                    Date  \
# Utility/Power Pool (NERC Region)
# NaN                                                           January
# Southwest Louisiana Electric Membership Corpora...  2010-01-06 00:00:00
# Progress Energy Florida (FRCC/SERC)                 2010-01-11 00:00:00
# Pacific Gas and Electric Company (WECC)             2010-01-18 00:00:00
# California ISO (WECC)                               2010-01-19 00:00:00
# San Diego Gas & Electric Company (WECC)             2010-01-19 00:00:00
# Los Angeles Department of Water and Power (WECC)    2010-01-20 00:00:00
# American Electric Power (SPP)                       2010-01-28 00:00:00
# NaN                                                           February
# Western Farmers Electric Cooperative (SPP)          2010-02-01 00:00:00
#
#                                                           Time  \
# Utility/Power Pool (NERC Region)
# ...

# %%
read_file_2010_copy = pd.DataFrame(read_file_2010['Date'])

# %%
read_file_2010_copy['Date'] = pd.to_datetime(read_file_2010_copy['Date'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1978         try:
# -> 1979             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1980             # If tzaware, these values represent unix timestamps, so we
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# <ipython-input-88-3239631ffda6> in <module>
# ----> 1 read_file_2010_copy['Date'] = pd.to_datetime(read_file_2010_copy['Date'])
#
# ...

# %%
read_file_2010_copy['Month'] = read_file_2010_copy.dt.month
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-ab9e634722e2> in <module>
# ----> 1 read_file_2010_copy['Month'] = read_file_2010_copy.dt.month
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5173             or name in self._accessors
#    5174         ):
# -> 5175             return object.__getattribute__(self, name)
#    5176         else:
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     173             # we're accessing the attribute of the class, i.e., Dataset.geo
#     174             return self._accessor
# --> 175         accessor_obj = self._accessor(obj)
#     176         # Replace the property with the accessor object. Inspired by:
# ...

# %%
read_file_2010_copy['Date'].unique
# Out:
# <bound method Series.unique of Utility/Power Pool (NERC Region)
# NaN                                                                                                   January
# Southwest Louisiana Electric Membership Corporation (SERC)                                  2010-01-06 00:00:00
# Progress Energy Florida (FRCC/SERC)                                                         2010-01-11 00:00:00
# Pacific Gas and Electric Company (WECC)                                                     2010-01-18 00:00:00
# California ISO (WECC)                                                                       2010-01-19 00:00:00
#                                                                                     ...
# Puget Sound Energy (WECC)                                                                   2010-11-22 00:00:00
# Pacific Gas and Electric (WECC)                                                             2010-11-23 00:00:00
# ...
