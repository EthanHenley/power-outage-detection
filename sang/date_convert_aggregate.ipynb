# %%
import os
import glob
import pandas as pd
os.chdir('./data/test')

# %%
extension = 'xlsx'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_excel(f,index_col=1, header = 1) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')

# %%
df = pd.read_csv('combined_csv.csv')

# %%
df
# Out:
#                                                   Year  Event Date and Time  \
# 0                                                 2012  01/09/2012  1:36 PM
# 1                                                 2012  01/10/2012  9:30 PM
# 2                                                 2012  01/19/2012  7:00 AM
# 3                                                 2012  02/19/2012  5:00 PM
# 4                                                 2012  02/28/2012  2:59 AM
# ..                                                 ...                  ...
# 741                                               2018  12/14/2018  4:00 PM
# 742                                               2018  12/14/2018  6:00 PM
# 743                                               2018  12/20/2018  9:30 AM
# 744                                               2018  12/27/2018  9:12 PM
# 745  Note: Customers affected are estimates and are...                  NaN
#
#     Restoration Date and Time              Duration  \
# 0         01/11/2012  1:05 AM  35 Hours, 29 Minutes
# 1         01/10/2012  9:30 PM   0 Hours,  0 Minutes
# 2         01/20/2012  3:00 PM  32 Hours,  0 Minutes
# 3         02/21/2012  7:33 AM  38 Hours, 33 Minutes
# 4         02/28/2012  6:12 AM   3 Hours, 13 Minutes
# ..                        ...                   ...
# 741       12/17/2018  2:00 AM  58 Hours,  0 Minutes
# 742                .        .   . Hours,  . Minutes
# 743       12/20/2018  5:00 PM   7 Hours, 30 Minutes
# 744       12/27/2018  9:16 PM   0 Hours,  4 Minutes
# 745                       NaN                   NaN
#
#                  Utility/Power Pool NERC Region  \
# 0          The Dow Chemical Company        SERC
# 1       Luminant Energy Company LLC         TRE
# 2                Puget Sound Energy        WECC
# 3           American Electric Power        SERC
# 4          Pacific Gas and Electric        WECC
# ..                              ...         ...
# 741              Puget Sound Energy        WECC
# 742      Snohomish County PUD No. 1        WECC
# 743              Puget Sound Energy        WECC
# 744  Consolidated Edison Co-NY Inc.        NPCC
# 745                             NaN         NaN
#
#                                          Area Affected  \
# 0                                            Louisiana
# 1                                   Rusk County, Texas
# 2       King, Pierce and Thurston Counties, Washington
# 3                    Kentucky, Virginia, West Virginia
# 4                               Sacramento, California
# ..                                                 ...
# 741  Washington: King County, Kitsap County, Island...
# 742                      Washington: Snohomish County;
# 743  Washington: Skagit County, Snohomish County, K...
# 744                         New York: New York County;
# 745                                                NaN
#
#                                    Type of Disturbance Loss (megawatts)  \
# 0                                            Load Shed              150
# 1                                            Load Shed              NaN
# 2                        Severe Weather - Winter Storm             1600
# 3                        Severe Weather - Winter Storm              UNK
# 4             Electrical System Separation (Islanding)                1
# ..                                                 ...              ...
# 741  Loss of electric service to more than 50,000 c...          Unknown
# 742  Loss of electric service to more than 50,000 c...              200
# 743  Loss of electric service to more than 50,000 c...          Unknown
# 744  Unexpected Transmission loss within its area, ...          Unknown
# 745                                                NaN              NaN
#
#     Number of Customers Affected
# 0                              1
# 1                            NaN
# 2                         426000
# 3                          90000
# 4                              1
# ..                           ...
# 741                       150000
# 742                        60000
# 743                       165000
# 744                      Unknown
# 745                          NaN
#
# [746 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# Year                             0
# Event Date and Time              7
# Restoration Date and Time        7
# Duration                         7
# Utility/Power Pool               7
# NERC Region                     23
# Area Affected                    7
# Type of Disturbance              7
# Loss (megawatts)                23
# Number of Customers Affected    23
# dtype: int64

# %%
df[df['Duration'].isnull() == True]
# Out:
#                                                   Year Event Date and Time  \
# 104  Note: Customers affected are estimates and are...                 NaN
# 199  Note: Customers affected are estimates and are...                 NaN
# 337  Note: Customers affected are estimates and are...                 NaN
# 437  Note: Customers affected are estimates and are...                 NaN
# 522  Note: Customers affected are estimates and are...                 NaN
# 617  Note: Customers affected are estimates and are...                 NaN
# 745  Note: Customers affected are estimates and are...                 NaN
#
#     Restoration Date and Time Duration Utility/Power Pool NERC Region  \
# 104                       NaN      NaN                NaN         NaN
# 199                       NaN      NaN                NaN         NaN
# 337                       NaN      NaN                NaN         NaN
# 437                       NaN      NaN                NaN         NaN
# 522                       NaN      NaN                NaN         NaN
# 617                       NaN      NaN                NaN         NaN
# 745                       NaN      NaN                NaN         NaN
#
#     Area Affected Type of Disturbance Loss (megawatts)  \
# 104           NaN                 NaN              NaN
# 199           NaN                 NaN              NaN
# 337           NaN                 NaN              NaN
# 437           NaN                 NaN              NaN
# 522           NaN                 NaN              NaN
# 617           NaN                 NaN              NaN
# 745           NaN                 NaN              NaN
#
#     Number of Customers Affected
# 104                          NaN
# 199                          NaN
# 337                          NaN
# 437                          NaN
# 522                          NaN
# 617                          NaN
# 745                          NaN

# %%
df = df.dropna(axis = 0)

# %%
df.isnull().sum()
# Out:
# Year                            0
# Event Date and Time             0
# Restoration Date and Time       0
# Duration                        0
# Utility/Power Pool              0
# NERC Region                     0
# Area Affected                   0
# Type of Disturbance             0
# Loss (megawatts)                0
# Number of Customers Affected    0
# dtype: int64

# %%
|
# Out:
#   File "<ipython-input-10-4b37ef281455>", line 1
#     |
#     ^
# SyntaxError: invalid syntax
